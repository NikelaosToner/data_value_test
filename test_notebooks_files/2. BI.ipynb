# %% [markdown]
# # Loading Libraries

# %%
import pandas as pd
import plotly.express as px
import os
import statsmodels
from datetime import date
import copy
os.chdir('/home/code/')

# %% [markdown]
# # Loading dfs

# %%
sales = pd.read_parquet('sales.parquet')
customers = pd.read_parquet('customers.parquet')
items = pd.read_parquet('items.parquet')
cities = pd.read_parquet('cities.parquet')

# %% [markdown]
# # Exploring dfs

# %%
sales.head(4)
# Out:
#   createdBy customerID                    ticketNumberDetail    value idType  \
# 0      None       None                                  None      NaN   None
# 1      None       None                                  None      NaN   None
# 2    victor   26557317  7AC93ADA-B4CA-EB11-B636-AC82478FB6A9  51100.0      C
# 3    victor   26557317  D44DFE12-B5CA-EB11-B636-AC82478FB6A9      1.0      C
#
#          date                          ticketNumber paymentMethod  itemID  \
# 0  2021-06-11  183C93C6-08CB-EB11-B636-AC82478FB6A9          None     NaN
# 1  2021-06-11  A938A208-09CB-EB11-B638-AC82478FA8AD          None     NaN
# 2  2021-06-11  916A5D76-B4CA-EB11-B636-AC82478FB6A9           CON   746.0
# 3  2021-06-11  916A5D76-B4CA-EB11-B636-AC82478FB6A9           CON  7530.0
#
#    discount  storeID                                            salesID
# 0       NaN       10               183C93C6-08CB-EB11-B636-AC82478FB6A9
# 1       NaN       10               A938A208-09CB-EB11-B638-AC82478FA8AD
# 2       0.0       10  916A5D76-B4CA-EB11-B636-AC82478FB6A97AC93ADA-B...
# 3       0.0       10  916A5D76-B4CA-EB11-B636-AC82478FB6A9D44DFE12-B...

# %%
customers.head(4)
# Out:
#               custCreationDate  cityId custHood                birthDate  \
# index
# 2      2013-01-26 00:00:00.000     1.0     None  2013-01-26 00:00:00.000
# 4      2021-03-18 00:00:00.000     1.0     None  1992-12-15 00:00:00.000
# 7      2021-05-19 00:00:00.000     1.0     None                     None
# 8      2013-02-13 00:00:00.000     1.0     None                     None
#
#        customerID             custEmail  gender  status
# index
# 2        26557317                  None     0.0       1
# 4      2041175771   SINOYKARI@GMAIL.COM     1.0       1
# 7        22576702                  None     0.0       1
# 8       691301004  secostasas@gmail.com     0.0       1

# %%
items.head(4)
# Out:
#                                 itemName  itemApplications             brand  \
# index
# 2             KYROFOSFAN NF FCO X 100 ML  GANADERÍA BOVINA           KYROVET
# 3             IMPOCONSUMO BOLSA PLASTICA           CONSUMO            VARIOS
# 4       PEDIGREE MINI BISCUIT X 100 GRMS          MASCOTAS          PEDIGREE
# 6      AGILITY PEQUEÑOS CACHORROS X 3 KG          MASCOTAS  ITALCOL MASCOTAS
#
#                     itemLine itemRegulated  businessUnit unitOfMeasure  \
# index
# 2      VITAMINAS Y MINERALES            NO  AGROPECUARIO          FCO
# 3         IMPLEMENTOS VARIOS            NO       CONSUMO          UND
# 4       ALIMENTO PARA PERROS            NO      MASCOTAS          UND
# 6       ALIMENTO PARA PERROS            NO      MASCOTAS          BOL
#
#               itemCreationDate               itemGroup            itemSubline  \
# index
# 2      2012-11-21 11:37:11.000           FARMACEUTICOS  FOSFORO PREPARACIONES
# 3      2017-07-12 18:03:36.000            LINEA VARIOS                   None
# 4      2019-10-02 14:59:21.000  ALIMENTOS CONCENTRADOS                 SNACKS
# 6      2016-08-24 11:42:55.000  ALIMENTOS CONCENTRADOS  SEGMENTO HIGH PREMIUM
#
#       category  itemID   itemLevel
# index
# 2         None   746.0   GAMA BAJA
# 3         None  7530.0   GAMA BAJA
# 4         None  8657.0  GAMA MEDIA
# 6       PERROS  6791.0   GAMA ALTA

# %%
cities.head(4)
# Out:
#        cityId  cityGrouper
# index
# 2         1.0      Capital
# 149     770.0  Non Capital
# 246     372.0  Non Capital
# 304     836.0  Non Capital

# %% [markdown]
# # Business Problems

# %% [markdown]
# 1. How are our sales grow by day, month and year? Is there a seasonal trend?

# %%
sales_ex_1 = sales[['value', 'date']]

# %%
sales_ex_1_day = sales_ex_1.groupby(by='date').sum().reset_index().sort_values(by='date')
sales_ex_1_month = copy.deepcopy(sales_ex_1)
sales_ex_1_month['month_year'] = pd.to_datetime(sales_ex_1.date).dt.to_period('M')
sales_ex_1_month = sales_ex_1_month.groupby(by='month_year').sum().reset_index().sort_values(by='month_year')
sales_ex_1_month.month_year = sales_ex_1_month.month_year.astype('str')
sales_ex_1_year = copy.deepcopy(sales_ex_1)
sales_ex_1_year['year'] = pd.to_datetime(sales_ex_1.date).dt.year
sales_ex_1_year = sales_ex_1_year.groupby(by='year').sum().reset_index().sort_values(by='year')
sales_ex_1_year.year = sales_ex_1_year.year.astype('str')

# %%
fig = px.line(sales_ex_1_day, x="date", y="value", title='Sales by day')
fig.update_traces(line_color='#1C70C9')
fig.show()
# Out:
# <div>                            <div id="23cf05a1-d235-40c7-a240-4d3bcf3fa36e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23cf05a1-d235-40c7-a240-4d3bcf3fa36e")) {                    Plotly.newPlot(                        "23cf05a1-d235-40c7-a240-4d3bcf3fa36e",                        [{"hovertemplate":"date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","line":{"color":"#1C70C9","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-02","2020-01-03","2020-01-04","2020-01-05","2020-01-06","2020-01-07","2020-01-08","2020-01-09","2020-01-10","2020-01-11","2020-01-12","2020-01-13","2020-01-14","2020-01-15","2020-01-16","2020-01-17","2020-01-18","2020-01-19","2020-01-20","2020-01-21","2020-01-22","2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-02-29","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-01","2020-04-02","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-02","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-06-01","2020-06-02","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-01","2020-07-02","2020-07-03","2020-07-04","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-11","2020-07-12","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-01","2020-08-02","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-12","2020-09-13","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020- ...

# %%
fig = px.line(sales_ex_1_month, x="month_year", y="value", title='Sales by month')
fig.update_traces(line_color='#A31F34')
fig.show()
# Out:
# <div>                            <div id="1c5f3735-6143-4ce1-9106-db3c230dc7a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c5f3735-6143-4ce1-9106-db3c230dc7a0")) {                    Plotly.newPlot(                        "1c5f3735-6143-4ce1-9106-db3c230dc7a0",                        [{"hovertemplate":"month_year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","line":{"color":"#A31F34","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[488615675.0,441374690.0,440594164.0,424708477.0,456310225.0,524120094.0,641880823.0,597902856.0,585939458.0,593450784.0,533112057.0,595458329.0,589883897.0,534760237.0,619067631.0,606229751.0,700636357.0,718648827.0,615819862.0,481451005.0,78121733.0,2367671.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0 ...

# %%
fig = px.line(sales_ex_1_year, x="year", y="value", title='Sales by year')
fig.show()
# Out:
# <div>                            <div id="521ecb43-26ee-410b-b6ac-2165370aea07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("521ecb43-26ee-410b-b6ac-2165370aea07")) {                    Plotly.newPlot(                        "521ecb43-26ee-410b-b6ac-2165370aea07",                        [{"hovertemplate":"year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2021"],"xaxis":"x","y":[6323467632.0,4946986971.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outli ...

# %% [markdown]
# There is a problem with the last two graphs. We don have full info about October and the 2021 for make a good comparison. In the case of the month periodical graph the solution could be skip October-2021 and take into account the other months. In case of year graph is not as simple because we only have two years, then could be better to use the mean instead of the sum of values by day.

# %%
# Months without October-2021
fig = px.line(sales_ex_1_month.iloc[:-1, :], x="month_year", y="value", title='Sales by month')
fig.update_traces(line_color='#A31F34')
fig.show()
# Out:
# <div>                            <div id="5911d160-8c97-480c-b7a0-d67c5e1ac29f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5911d160-8c97-480c-b7a0-d67c5e1ac29f")) {                    Plotly.newPlot(                        "5911d160-8c97-480c-b7a0-d67c5e1ac29f",                        [{"hovertemplate":"month_year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","line":{"color":"#A31F34","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09"],"xaxis":"x","y":[488615675.0,441374690.0,440594164.0,424708477.0,456310225.0,524120094.0,641880823.0,597902856.0,585939458.0,593450784.0,533112057.0,595458329.0,589883897.0,534760237.0,619067631.0,606229751.0,700636357.0,718648827.0,615819862.0,481451005.0,78121733.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"# ...

# %%
# average_year
sales_ex_1_year = copy.deepcopy(sales_ex_1)
sales_ex_1_year['year'] = pd.to_datetime(sales_ex_1.date).dt.year
sales_ex_1_year = sales_ex_1_year.groupby(by='year').mean().reset_index().sort_values(by='year')
sales_ex_1_year.year = sales_ex_1_year.year.astype('str')
fig = px.line(sales_ex_1_year, x="year", y="value", title='Sales by year')
fig.show()
# Out:
# <div>                            <div id="5ce2a1ce-0dc5-41a5-8fdd-a80f1e2e5dc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ce2a1ce-0dc5-41a5-8fdd-a80f1e2e5dc2")) {                    Plotly.newPlot(                        "5ce2a1ce-0dc5-41a5-8fdd-a80f1e2e5dc2",                        [{"hovertemplate":"year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020","2021"],"xaxis":"x","y":[20324.524329449578,22045.396483957218],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"color ...

# %% [markdown]
# That shows the opposite trend! Which means that the average sales in 2021 have been better than the average sales in 2021

# %% [markdown]
# Is there an seasonal trend? We can't say that watching year and month plots but lets take a closer look in days. What if we analyze sales by day of week? What could we find?

# %%
sales_ex_1_day = sales_ex_1.groupby(by='date').sum().reset_index().sort_values(by='date')
sales_ex_1_day['day_of_week'] = pd.to_datetime(sales_ex_1_day.date).dt.weekday
sales_ex_1_day = sales_ex_1_day.groupby(by='day_of_week').mean().reset_index()
replace_days = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
sales_ex_1_day['day_name'] = sales_ex_1_day['day_of_week'].replace(replace_days)

# %%
fig = px.bar(sales_ex_1_day, x='day_name', y='value', color='day_name', title='Average of sales by weekday')
fig.show()
# Out:
# <div>                            <div id="e785c53b-46a5-41c4-bbb4-8b9708d32d5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e785c53b-46a5-41c4-bbb4-8b9708d32d5f")) {                    Plotly.newPlot(                        "e785c53b-46a5-41c4-bbb4-8b9708d32d5f",                        [{"alignmentgroup":"True","hovertemplate":"day_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Mon","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mon","offsetgroup":"Mon","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon"],"xaxis":"x","y":[18790607.460674156],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Tue","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Tue","offsetgroup":"Tue","orientation":"v","showlegend":true,"textposition":"auto","x":["Tue"],"xaxis":"x","y":[21025181.260869566],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Wed","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Wed","offsetgroup":"Wed","orientation":"v","showlegend":true,"textposition":"auto","x":["Wed"],"xaxis":"x","y":[20366363.704545453],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Thu","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Thu","offsetgroup":"Thu","orientation":"v","showlegend":true,"textposition":"auto","x":["Thu"],"xaxis":"x","y":[19581553.431818184],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Fri","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Fri","offsetgroup":"Fri","orientation":"v","showlegend":true,"textposition":"auto","x":["Fri"],"xaxis":"x","y":[21831064.65882353],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Sat","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Sat","offsetgroup":"Sat","orientation":"v","showlegend":true,"textposition":"auto","x":["Sat"],"xaxis":"x","y":[20565827.238636363],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"day_name=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Sun","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sun","offsetgroup":"Sun","orientation":"v","showlegend":true,"textposition":"auto","x":["Sun"],"xaxis":"x","y":[5818359.78313253],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"c ...

# %% [markdown]
# From the graph above we can conclude that there is a clear seasonal trend: the Sundays the average value of sales decreases a lot, maybe because that day the store is not open all the day or is just working online.

# %%
# Cleaning memory

del replace_days
del fig
del sales_ex_1
del sales_ex_1_day 
del sales_ex_1_month 
del sales_ex_1_year

# %% [markdown]
# ------------------------

# %% [markdown]
# 2. How is the distribution of our sales by the use/application of each item for our customer

# %% [markdown]
# First, we see that there is a lot more productos for pets than for other categories.

# %%
item_applications_ex_2 = items.itemApplications.value_counts().reset_index().rename(columns = {
                                                            'index':'itemApplications', 
                                                            'itemApplications':'quantity'})

# %%
fig = px.pie(item_applications_ex_2, values='quantity', names='itemApplications', 
             title='Quantity of items by itemApplications')
fig.show()
# Out:
# <div>                            <div id="4d643e1e-ea38-4c2a-8e09-8c99f1bb2540" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d643e1e-ea38-4c2a-8e09-8c99f1bb2540")) {                    Plotly.newPlot(                        "4d643e1e-ea38-4c2a-8e09-8c99f1bb2540",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"itemApplications=%{label}<br>quantity=%{value}<extra></extra>","labels":["MASCOTAS","GANADER\u00cdA BOVINA","AGRICULTURA","JARDINERIA","CONSUMO","PRODUCCI\u00d3N EQUINA","AVICULTURA","PORCICULTURA","NO APLICA","ACUICULTURA","CUNICULTURA"],"legendgroup":"","name":"","showlegend":true,"values":[2338,878,371,164,117,112,63,29,9,5,2],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sc ...

# %% [markdown]
# Does that trend remains over our sales?

# %%
sales_ex_2 = copy.deepcopy(sales)
items_ex_2 = copy.deepcopy(items)
sales_ex_2 = sales_ex_2[['itemID', 'value']]
sales_ex_2 = sales_ex_2.dropna()
items_ex_2 = items_ex_2[['itemID', 'itemApplications']]
merge_ex_2 = sales_ex_2.merge(items_ex_2, how='inner', left_on='itemID', right_on='itemID').drop(columns='itemID')

# %%
merge_ex_2_sum = merge_ex_2.groupby(by='itemApplications').sum().reset_index()
fig = px.pie(merge_ex_2_sum, values='value', names='itemApplications', title='Sales by itemApplications')
fig.show()
# Out:
# <div>                            <div id="fb713bf9-960e-44bf-bf2e-3fbb869b2acb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb713bf9-960e-44bf-bf2e-3fbb869b2acb")) {                    Plotly.newPlot(                        "fb713bf9-960e-44bf-bf2e-3fbb869b2acb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"itemApplications=%{label}<br>value=%{value}<extra></extra>","labels":["ACUICULTURA","AGRICULTURA","AVICULTURA","CONSUMO","CUNICULTURA","GANADER\u00cdA BOVINA","JARDINERIA","MASCOTAS","NO APLICA","PORCICULTURA","PRODUCCI\u00d3N EQUINA"],"legendgroup":"","name":"","showlegend":true,"values":[23158640.0,1769125438.0,149168288.0,342891494.0,18743578.0,2396198492.0,84803125.0,5917680798.0,775501.0,280727141.0,281462770.0],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true, ...

# %% [markdown]
# Actually the sales of each category has correspondence with the quantity of products that we have per each line. This can indicates a behaviour that the shop has been having across its existence: The product lines with more sales have been increasing faster than the others. However, the participation of pet products on the total sales is smaller than its participation over items and the participation of agricultural products in sales is much bigger than its participation on items. Maybe could be interesting to explore the possibility of increase the item stock that we have on agricultural products in the future. Lets see another chart of average sale by each category. take into account that this average is done over the Ticket detailed and not over the whole sale done by a client at a time.

# %%
merge_ex_2_mean = merge_ex_2.groupby(by='itemApplications').mean().reset_index()
fig = px.pie(merge_ex_2_mean, values='value', names='itemApplications', title='Average sales by itemApplications')
fig.show()
# Out:
# <div>                            <div id="c044c8fc-6b9b-4aa5-a9b4-de380515dfd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c044c8fc-6b9b-4aa5-a9b4-de380515dfd5")) {                    Plotly.newPlot(                        "c044c8fc-6b9b-4aa5-a9b4-de380515dfd5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"itemApplications=%{label}<br>value=%{value}<extra></extra>","labels":["ACUICULTURA","AGRICULTURA","AVICULTURA","CONSUMO","CUNICULTURA","GANADER\u00cdA BOVINA","JARDINERIA","MASCOTAS","NO APLICA","PORCICULTURA","PRODUCCI\u00d3N EQUINA"],"legendgroup":"","name":"","showlegend":true,"values":[143842.4844720497,33718.1794236487,13793.997410763825,2862.8446644903274,6381.878787878788,30730.737066201553,13899.872971643992,23022.412068160596,5275.517006802721,74860.57093333334,72861.18819570282],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"out ...

# %% [markdown]
# What a surprise! Products with small participation over the item type and the total sales have the biggest average sale value! What can that mean? Maybe those are the most expensive products but just a little portion of customers buy into this line. Thats an attention call, there could be a big market concentration in this products.

# %%
# Cleaning memory

del item_applications_ex_2
del sales_ex_2 
del items_ex_2
del merge_ex_2
del merge_ex_2_sum
del merge_ex_2_mean
del fig

# %% [markdown]
# --------------------------

# %% [markdown]
# 3. Why our sales have fall from Jun 2021 to Sept 2021?

# %%
grouper_list = ['itemApplications', 'itemRegulated',
       'businessUnit', 'itemGroup', 'category', 'itemLevel']
for grouper_variable in grouper_list:
    sales_ex_3 = copy.deepcopy(sales)
    items_ex_3 = copy.deepcopy(items)
    sales_ex_3 = sales_ex_3[['date','itemID', 'value']]
    sales_ex_3 = sales_ex_3.dropna()
    items_ex_3 = items_ex_3[['itemID', grouper_variable]]
    merge_ex_3 = sales_ex_3.merge(items_ex_3, how='inner', left_on='itemID', right_on='itemID').drop(columns='itemID')
    merge_ex_3.date = pd.to_datetime(merge_ex_3.date)
    merge_ex_3.date = merge_ex_3.date.dt.to_period('M')
    merge_ex_3 = merge_ex_3.sort_values(by='date').groupby(by=['date', grouper_variable]).sum().reset_index()
    merge_ex_3.date = merge_ex_3.date.astype(str)
    fig = px.area(merge_ex_3, x="date", y="value", color=grouper_variable, title=f'Area sales by {grouper_variable}')
    fig.show()
# Out:
# <div>                            <div id="966b7ccb-9300-4f7b-bb33-9f6f27b05c8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("966b7ccb-9300-4f7b-bb33-9f6f27b05c8d")) {                    Plotly.newPlot(                        "966b7ccb-9300-4f7b-bb33-9f6f27b05c8d",                        [{"hovertemplate":"itemApplications=ACUICULTURA<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"
0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0, ...
# <div>                            <div id="db1ec2ea-aa03-4b15-a0f3-80b59ab3d5a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db1ec2ea-aa03-4b15-a0f3-80b59ab3d5a0")) {                    Plotly.newPlot(                        "db1ec2ea-aa03-4b15-a0f3-80b59ab3d5a0",                        [{"hovertemplate":"itemLevel=GAMA ALTA<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"GAMA ALTA","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"GAMA ALTA","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[234550448.0,200873247.0,203063103.0,202389889.0,215059313.0,263022997.0,307995730.0,284273594.0,266804142.0,266739093.0,232618287.0,274905828.0,263078272.0,228041967.0,271112890.0,269406578.0,321535220.0,341938539.0,288353907.0,212885938.0,31425757.0,1458331.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"itemLevel=GAMA BAJA<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"GAMA BAJA","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"GAMA BAJA","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[91316779.0,90474206.0,86094836.0,74231421.0,85717529.0,96195030.0,125963527.0,112264936.0,117191711.0,121860204.0,115457561.0,118237498.0,122285515.0,116103909.0,132403698.0,131082180.0,147401781.0,133543880.0,114397637.0,105757861.0,19037358.0,367995.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"itemLevel=GAMA MEDIA<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"GAMA MEDIA","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"GAMA MEDIA","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[162373043.0,149688767.0,151199993.0,147776968.0,155306185.0,164641219.0,207530183.0,200888368.0,201606070.0,204550199.0,184743314.0,201844373.0,204326759.0,190442559.0,215167659.0,205439576.0,231179506.0,242395483.0,212297922.0,162462445.0,27550038.0,541345.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpe ...

# %%
grouper_list = ['cityId', 'gender', 'PDV_or_not']
for grouper_variable in grouper_list:
    sales_ex_3 = copy.deepcopy(sales)
    items_ex_3 = copy.deepcopy(customers)
    sales_ex_3 = sales_ex_3[['date','customerID', 'value']]
    sales_ex_3 = sales_ex_3.dropna()
    items_ex_3 = items_ex_3[['customerID', grouper_variable]]
    merge_ex_3 = sales_ex_3.merge(items_ex_3, how='inner', left_on='customerID', 
                                  right_on='customerID').drop(columns='customerID')
    merge_ex_3.date = pd.to_datetime(merge_ex_3.date)
    merge_ex_3.date = merge_ex_3.date.dt.to_period('M')
    merge_ex_3 = merge_ex_3.sort_values(by='date').groupby(by=['date', grouper_variable]).sum().reset_index()
    merge_ex_3.date = merge_ex_3.date.astype(str)
    fig = px.area(merge_ex_3, x="date", y="value", color=grouper_variable, title=f'Area sales by {grouper_variable}')
    fig.show()
# Out:
# <div>                            <div id="fd3bd5e0-f9bc-418c-ac33-b734373ac7a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd3bd5e0-f9bc-418c-ac33-b734373ac7a7")) {                    Plotly.newPlot(                        "fd3bd5e0-f9bc-418c-ac33-b734373ac7a7",                        [{"hovertemplate":"cityId=1.0<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"1.0","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"1.0","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[381684105.0,339695271.0,336888217.0,346490821.0,366412762.0,433620566.0,507128222.0,477169253.0,477527215.0,500012018.0,444302216.0,487372965.0,466232165.0,437837587.0,503314888.0,500345567.0,575084948.0,572088745.0,510654437.0,395915723.0,54917075.0,1879428.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"cityId=52.0<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"52.0","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"52.0","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-06","2020-07","2020-09","2020-10","2020-11","2021-03","2021-06","2021-08","2021-09"],"xaxis":"x","y":[26000.0,42542.0,49418.0,129411.0,50138.0,277842.0,40501.0,263544.0,75854.0,206135.0,40857.0,72478.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"cityId=78.0<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"78.0","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"78.0","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-08","2020-09","2020-10","2020-11","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-
0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl" ...

# %%
grouper_list = ['createdBy', 'idType','paymentMethod','storeID']
for grouper_variable in grouper_list:
    sales_ex_3 = copy.deepcopy(sales)
    items_ex_3 = copy.deepcopy(customers)
    sales_ex_3 = sales_ex_3[['date','customerID', 'value', grouper_variable]]
    sales_ex_3 = sales_ex_3.dropna()
    items_ex_3 = items_ex_3[['customerID']]
    merge_ex_3 = sales_ex_3.merge(items_ex_3, how='inner', left_on='customerID', 
                                  right_on='customerID').drop(columns='customerID')
    merge_ex_3.date = pd.to_datetime(merge_ex_3.date)
    merge_ex_3.date = merge_ex_3.date.dt.to_period('M')
    merge_ex_3 = merge_ex_3.sort_values(by='date').groupby(by=['date', grouper_variable]).sum().reset_index()
    merge_ex_3.date = merge_ex_3.date.astype(str)
    fig = px.area(merge_ex_3, x="date", y="value", color=grouper_variable, title=f'Area sales by {grouper_variable}')
    fig.show()
# Out:
# <div>                            <div id="b13de131-6f1b-47a9-bff8-aecbe2354bc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b13de131-6f1b-47a9-bff8-aecbe2354bc2")) {                    Plotly.newPlot(                        "b13de131-6f1b-47a9-bff8-aecbe2354bc2",                        [{"hovertemplate":"createdBy=amin<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"amin","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"amin","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[95601865.0,98152761.0,93540775.0,49487982.0,143543699.0,182860176.0,223594907.0,194508786.0,195637119.0,183015125.0,149714331.0,139372214.0,139377968.0,122718563.0,146166531.0,143106054.0,167343235.0,159635749.0,119066535.0,95880761.0,28998840.0,391224.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"createdBy=ericda<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ericda","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"ericda","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[104863157.0,95766222.0,92691476.0,87976009.0,94232276.0,108918521.0,109225171.0,86982480.0,120886513.0,138226161.0,112957468.0,126182179.0,122708773.0,130376519.0,136901926.0,132409633.0,139075495.0,166594145.0,150211855.0,108051396.0,10417412.0,31430.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"createdBy=frank cafiel<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"frank cafiel","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"frank cafiel","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-06","2020-10","2020-11"],"xaxis":"x","y":[5774725.0,5852551.0,5494319.0,1379909.0,2693365.0,2697834.0,4230567.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"createdBy=jannys<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"jannys","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"jannys","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[38367935.0,68679617.0,70566351.0,48799965.0,11429898.0,21634542.0,31823916.0,68646015.0,71248391.0,49546016.0,67386168.0,67246656.0,62388935.0,54038073.0,68104029.0,58404863.0,82012488.0,69919696.0,14153039.0,49898494.0,8726702.0,861369.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"createdBy=jmenco<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"jmenco","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"jmenco","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09"],"xaxis":"x","y":[5472885.0,109295725.0,113737622.0,92981007.0,90478884.0,77220134.0,85162050.0,116206706.0,151311759.0,146748330.0,135685783.0,144413217.0,143430449.0,2420714.0,2253925.0,4436596.0,5201414.0,3975097.0,5347393.0,7809784.0,3474362.0],"yaxis":"y","type":"scat ...
# <div>                            <div id="09a18838-f7c0-4425-8f1a-c2213f25d178" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09a18838-f7c0-4425-8f1a-c2213f25d178")) {                    Plotly.newPlot(                        "09a18838-f7c0-4425-8f1a-c2213f25d178",                        [{"hovertemplate":"idType=C<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"C","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"C","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10"],"xaxis":"x","y":[476109568.0,427604981.0,422724814.0,403998518.0,436150714.0,508393821.0,621480471.0,573165310.0,564725858.0,569013801.0,516474189.0,576407240.0,562485934.0,518309313.0,599183118.0,590984403.0,679047003.0,700602592.0,599826865.0,463489994.0,76059187.0,2367671.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"idType=E<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"E","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"E","orientation":"v","showlegend":true,"stackgroup":"1","x":["2020-01","2020-02","2020-03","2020-04","2020