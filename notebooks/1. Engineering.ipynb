# %% [markdown]
# # Loading Libraries

# %%
from IPython.display import Image
import pandas as pd
import numpy as np
import os
import re
import random
import datetime

os.chdir('/home/code/')

# %% [markdown]
# # Loading Dataframe (parquet)

# %%
df = pd.read_parquet('customerData.parquet')
df = df.drop(columns='Unnamed: 0')

# %% [markdown]
# # Data Profiling Calculation
# In this section some metrics are calculate from the df trying guarantee the **data quality**. We are going to calculate values like number of nulls in columns, min and max number of characters, number of unique values for each column and so on. Also, we will calculate, for variable type **date**, **id** and **email**, the number of values which doesn't match on a given **pattern** that determines the **correct format** of the variable. We're going to start with that measure.

# %% [markdown]
# First, lets take a look over the dataframe in order to know what we understand by **correct format** of each variable. A random sample of 10 registers will be useful for that.

# %%
df.sample(10)
# Out:
#        customerID        date paymentMethod  \
# 404056   03717202  2021-07-29           CON
# 130767        PDV  2020-07-20           CON
# 119813        PDV  2020-11-12           CON
# 262234    3092909  2021-05-05           CON
# 228230   52177000  2020-05-21           CON
# 519957   02969426  2021-03-15           CON
# 351363        PDV  2020-12-29           CON
# 298800    9318059  2020-03-18           CON
# 90758         PDV  2021-04-09           CON
# 177199        PDV  2021-04-15           CON
#
#                                 ticketNumber  \
# 404056  23BFFA38-AEF0-EB11-A47C-A4BB6DA98B46
# 130767  ABCEC75F-99CA-EA11-9EBB-448A5B481A00
# 119813  23443AB7-FA24-EB11-9EC2-448A5B481A00
# 262234  1D041D80-E6AD-EB11-A45E-A4BB6DA98B46
# 228230  3E7AA4EE-769B-EA11-B9AA-842B2BAAF117
# 519957  78F8FC7D-A285-EB11-997D-842B2BAAF117
# 351363  EF6C5C59-244A-EB11-9ECB-448A5B481A00
# 298800  8447E7ED-2869-EA11-9626-D8CB8A448819
# 90758   05B80D36-7999-EB11-9ED2-448A5B481A00
# 177199  7B731BF2-2D9E-EB11-BD65-8A42798E778C
#
#                           ticketNumberDetail      value  discount createdBy  \
# 404056  24BFFA38-AEF0-EB11-A47C-A4BB6DA98B46    38000.0       0.0      amin
# 130767  D322A073-99CA-EA11-9EBB-448A5B481A00     4286.0       0.0    ericda
# 119813  24443AB7-FA24-EB11-9EC2-448A5B481A00    10252.0       0.0    ericda
# 262234  1E041D80-E6AD-EB11-A45E-A4BB6DA98B46     7227.0       0.0      amin
# 228230  33E691F6-769B-EA11-B9AA-842B2BAAF117    12605.0       0.0    jannys
# 519957  79F8FC7D-A285-EB11-997D-842B2BAAF117    17300.0       0.0    victor
# 351363  12595077-244A-EB11-9ECB-448A5B481A00     7429.0       0.0    ericda
# 298800  8547E7ED-2869-EA11-9626-D8CB8A448819  3660000.0   73200.0    jmenco
# 90758   06B80D36-7999-EB11-9ED2-448A5B481A00     6667.0       0.0    ericda
# 177199  7C731BF2-2D9E-EB11-BD65-8A42798E778C    16219.0       0.0    luisfg
#
#                custCreationDate idType  ...                       itemLine  \
# 404056  2016-02-12 00:00:00.000      C  ...          VITAMINAS Y MINERALES
# 130767  2013-01-02 00:00:00.000      C  ...                         SNACKS
# 119813  2013-01-02 00:00:00.000      C  ...     REPUESTOS PARA FUMIGADORAS
# 262234  2013-02-06 00:00:00.000      C  ...   PUNTILLAS Y CLAVOS DE VARETA
# 228230  2014-11-28 00:00:00.000      C  ...     REPUESTOS PARA FUMIGADORAS
# 519957  2016-04-11 00:00:00.000      C  ...               ANTIPARASITARIOS
# 351363  2013-01-02 00:00:00.000      C  ...           ALIMENTO PARA PERROS
# 298800  2020-02-21 00:00:00.000      C  ...                    PLAGUICIDAS
# 90758   2013-01-02 00:00:00.000      C  ...            ALIMENTO PARA GATOS
# 177199  2013-01-02 00:00:00.000      C  ...  COSMETICOS Y/O DERMATOLOGICOS
#
#                    itemSubline itemRegulated  itemApplications   itemLevel  \
# 404056  COMPUESTOS Y MINERALES            NO  GANADERÍA BOVINA  GAMA MEDIA
# 130767                  HUESOS            NO          MASCOTAS   GAMA BAJA
# 119813                    None            NO       AGRICULTURA   GAMA ALTA
# 262234                    None            NO  GANADERÍA BOVINA   GAMA BAJA
# 228230                    None            NO       AGRICULTURA   GAMA ALTA
# 519957         ANTIHELMINTICOS            NO          MASCOTAS   GAMA ALTA
# 351363         ALIMENTO HUMEDO            NO          MASCOTAS  GAMA MEDIA
# 298800            INSECTICIDAS            NO       AGRICULTURA  GAMA MEDIA
# 90758       SEGMENTO ECONOMICO            NO          MASCOTAS   GAMA BAJA
# 177199                 CHAMPUS            NO          MASCOTAS   GAMA BAJA
#
#         storeID dayOfYear dayOfWeek yearMonth    dayName
# 404056       17       210         5   2021-07   Thursday
# 130767       16       202         2   2020-07     Monday
# 119813       16       317         5   2020-11   Thursday
# 262234       17       125         4   2021-05  Wednesday
# 228230       10       142         5   2020-05   Thursday
# 519957       10        74         2   2021-03     Monday
# 351363       16       364         3   2020-12    Tuesday
# 298800       16        78         4   2020-03  Wednesday
# 90758        16        99         6   2021-04     Friday
# 177199       17       105         5   2021-04   Thursday
#
# [10 rows x 33 columns]

# %% [markdown]
# In the last sample we can see things like: ```date``` comes in date format, but other time variables comes in datetime. There are a very clear rule for identify the ticket number, some ids are ints or floats (which can suggest the presence of null values) and so on. We will be using **regex** to create patterns that express those rules and filter the data looking for wrong entrances.

# %% [markdown]
# The three next functions process the df, select the columns with wrong entrances and return the number of wrong entrances per column and the wrong values with its **frequency**.

# %%
def pattern_match(value, pattern):
    value = str(value)
    if re.fullmatch(pattern, value) == None:
        return False
    else:
        return True

# %%
def filter_matches(data_f, col_name, pattern):
    base_series = data_f[col_name].dropna()
    bool_column = base_series.apply(pattern_match, args=(pattern))
    result = base_series[~(bool_column)] 
    num_not_match = bool_column.count() - bool_column.sum()
    errors = result.value_counts().reset_index()

    return num_not_match, errors

# %%
def patternizer(df):
    
    dict_of_re_patterns = {'date': ['\d{4,4}-\d{2,2}-\d{2,2}'],
                       'customerID':['\d*'],
                      'ticketNumber':['[\dA-Z]{8,8}-[\dA-Z]{4,4}-[\dA-Z]{4,4}-[\dA-Z]{4,4}-[\dA-Z]{12,12}'],
                      'ticketNumberDetail':['[\dA-Z]{8,8}-[\dA-Z]{4,4}-[\dA-Z]{4,4}-[\dA-Z]{4,4}-[\dA-Z]{12,12}'],
                      'custCreationDate':['\d{4,4}-\d{2,2}-\d{2,2} \d{2,2}:\d{2,2}:\d{2,2}\.\d{3,3}'],
                      'birthDate':['\d{4,4}-\d{2,2}-\d{2,2} \d{2,2}:\d{2,2}:\d{2,2}\.\d{3,3}'],
                      'custCity':['\d+.?\d*'],
                      'custEmail':['[-\.\w]+@[\w]+\.[\w]+\.?[\w]*.?[\w]* *'],
                      'itemID':['\d+.?\d*'],
                      'itemCreationDate':['\d{4,4}-\d{2,2}-\d{2,2} \d{2,2}:\d{2,2}:\d{2,2}\.\d{3,3}'],
                      'storeID':['\d+.?\d*']}
    
    not_match_values = {}
    errors_dict = {}
    for index,value in dict_of_re_patterns.items():
        num, error = filter_matches(df, index,value)
        not_match_values[index]= num
        if error.shape[0]==0:
            continue
        else:
            errors_dict[index]=error
            
    return not_match_values, errors_dict

# %% [markdown]
# We can now calculate the wrong entrances but also the other measures that will be into the data profiling process

# %%
not_match_values, errors_dict = patternizer(df)

# %%
count_dict = {x: df.shape[0] for x in df.columns.tolist()}
not_null = df.notna().sum()
null_dict_total = df.isna().sum()
null_dict_perc=(null_dict_total/df.shape[0]).to_dict()

# %%
def count_characters(value):
    return len(value)

# %%
characters = df.astype(str).applymap(count_characters)
characters_max = characters.max()
characters_min = characters.min()
del characters

# %%
def unique_values(df):
    unique = {}
    
    for column in df.columns.tolist():
        unique[column] = len(df[column].unique().tolist())
    return unique

# %%
unique_values_dict = unique_values(df)

# %% [markdown]
# # Data Profiling Results
# Once we have our metrics is time to display them in order to understand the data more deeply.

# %%
cols_names = ['not_match_regex','count', 'not_null_total', 'null_total', 'null_percentaje', 'max_characters',
             'min_characters', 'unique_values']

# %%
pd.DataFrame([not_match_values,count_dict, not_null, null_dict_total, null_dict_perc, 
             characters_max, characters_min, unique_values_dict], index=cols_names).transpose(
        ).sort_values(by='unique_values')
# Out:
#                     not_match_regex     count  not_null_total  null_total  \
# storeID                         0.0  538421.0        538421.0         0.0
# itemRegulated                   NaN  538421.0        534977.0      3444.0
# businessUnit                    NaN  538421.0        535028.0      3393.0
# category                        NaN  538421.0        217763.0    320658.0
# gender                          NaN  538421.0        534112.0      4309.0
# itemLevel                       NaN  538421.0        534982.0      3439.0
# paymentMethod                   NaN  538421.0        535527.0      2894.0
# dayOfWeek                       NaN  538421.0        538421.0         0.0
# idType                          NaN  538421.0        534112.0      4309.0
# dayName                         NaN  538421.0        538421.0         0.0
# itemApplications                NaN  538421.0        535028.0      3393.0
# itemGroup                       NaN  538421.0        535028.0      3393.0
# yearMonth                       NaN  538421.0        538421.0         0.0
# createdBy                       NaN  538421.0        535525.0      2896.0
# unitOfMeasure                   NaN  538421.0        535028.0      3393.0
# custCity                        0.0  538421.0        534102.0      4319.0
# itemLine                        NaN  538421.0        533170.0      5251.0
# itemSubline                     NaN  538421.0        356536.0    181885.0
# custHood                        NaN  538421.0          3351.0    535070.0
# brand                           NaN  538421.0        535028.0      3393.0
# dayOfYear                       NaN  538421.0        538421.0         0.0
# date                            0.0  538421.0        538421.0         0.0
# discount                        NaN  538421.0        535525.0      2896.0
# custEmail                     155.0  538421.0         40370.0    498051.0
# custCreationDate                0.0  538421.0        534112.0      4309.0
# itemCreationDate                0.0  538421.0        535028.0      3393.0
# birthDate                  463132.0  538421.0        534112.0      4309.0
# itemName                        NaN  538421.0        535028.0      3393.0
# itemID                          0.0  538421.0        535028.0      3393.0
# value                           NaN  538421.0        535525.0      2896.0
# customerID                 396941.0  538421.0        534112.0      4309.0
# ticketNumber                    0.0  538421.0        538421.0         0.0
# ticketNumberDetail              0.0  538421.0        535525.0      2896.0
#
#                     null_percentaje  max_characters  min_characters  \
# storeID                    0.000000             2.0             2.0
# itemRegulated              0.006396             4.0             2.0
# businessUnit               0.006302            12.0             4.0
# category                   0.595553             6.0             4.0
# gender                     0.008003             3.0             3.0
# itemLevel                  0.006387            10.0             4.0
# paymentMethod              0.005375             4.0             3.0
# dayOfWeek                  0.000000             1.0             1.0
# idType                     0.008003             4.0             1.0
# dayName                    0.000000             9.0             6.0
# itemApplications           0.006302            17.0             4.0
# itemGroup                  0.006302            26.0             4.0
# yearMonth                  0.000000             7.0             7.0
# createdBy                  0.005379            12.0             4.0
# unitOfMeasure              0.006302             4.0             4.0
# custCity                   0.008022             5.0             3.0
# itemLine                   0.009753            39.0             4.0
# itemSubline                0.337812            40.0             4.0
# custHood                   0.993776            27.0             4.0
# brand                      0.006302            24.0             2.0
# dayOfYear                  0.000000             3.0             1.0
# date                       0.000000            10.0            10.0
# discount                   0.005379             8.0             3.0
# custEmail                  0.925021            47.0             1.0
# custCreationDate           0.008003            23.0             4.0
# itemCreationDate           0.006302            23.0             4.0
# birthDate                  0.008003            23.0             3.0
# itemName                   0.006302            40.0             4.0
# itemID                     0.006302             6.0             3.0
# value                      0.005379             9.0             3.0
# customerID                 0.008003            20.0             1.0
# ticketNumber               0.000000            36.0            36.0
# ticketNumberDetail         0.005379            36.0             4.0
#
#                     unique_values
# storeID                       3.0
# itemRegulated                 3.0
# businessUnit                  4.0
# category                      4.0
# gender                        4.0
# itemLevel                     4.0
# paymentMethod                 6.0
# dayOfWeek                     7.0
# idType                        7.0
# dayName                       7.0
# itemApplications             12.0
# itemGroup                    17.0
# yearMonth                    22.0
# createdBy                    23.0
# unitOfMeasure                31.0
# custCity                     52.0
# itemLine                     93.0
# itemSubline                 116.0
# custHood                    127.0
# brand                       131.0
# dayOfYear                   364.0
# date                        613.0
# discount                   1051.0
# custEmail                  2456.0
# custCreationDate           2712.0
# itemCreationDate           2732.0
# birthDate                  3840.0
# itemName                   4083.0
# itemID                     4089.0
# value                      5023.0
# customerID                17083.0
# ticketNumber             278279.0
# ticketNumberDetail       535526.0

# %%
df.describe()[['value','discount']].round(1)
# Out:
#            value  discount
# count   535525.0  535525.0
# mean     21045.6      57.8
# std      49597.4    1396.1
# min          0.0       0.0
# 25%       4000.0       0.0
# 50%      10000.0       0.0
# 75%      22800.0       0.0
# max    7600000.0  378000.0

# %% [markdown]
# We can also view the wrong data filter above and the unique values of some variables like, for example ```storeID```, ```category``` and ```itemGroup```

# %% [markdown]
# # Unique values

# %%
df.storeID.value_counts().reset_index().rename(columns={'index':'storeID', 'storeID':'frequency'})
# Out:
#    storeID  frequency
# 0       16     284616
# 1       17     175287
# 2       10      78518

# %%
df.category.value_counts().reset_index().rename(columns={'index':'category', 'category':'frequency'})
# Out:
#   category  frequency
# 0   PERROS     191601
# 1    GATOS      25143
# 2     AVES       1019

# %%
df.itemGroup.value_counts().reset_index().rename(columns={'index':'itemGroup', 'itemGroup':'frequency'})
# Out:
#                      itemGroup  frequency
# 0                FARMACEUTICOS     195017
# 1       ALIMENTOS CONCENTRADOS     124521
# 2                 LINEA VARIOS      93775
# 3                 AGROQUIMICOS      46732
# 4                    DOMESTICO      22630
# 5                   ACCESORIOS      19946
# 6                   FERRETERIA      10166
# 7                 INSTRUMENTAL       6659
# 8          SALES Y SUPLEMENTOS       4821
# 9                     SEMILLAS       4668
# 10                   REPUESTOS       2792
# 11                      CUAJOS       1570
# 12                     EQUIPOS       1563
# 13                   SERVICIOS        146
# 14  PLASTICOS AGROINDUSTRIALES         21
# 15               PROMOCIONALES          1

# %% [markdown]
# # Wrong values

# %%
errors_dict['customerID'].rename(columns={'index':'customerID', 'customerID':'frequency'})
# Out:
#               customerID  frequency
# 0                    PDV     396849
# 1              64617-248         33
# 2                OOACRGS         31
# 3                      p          7
# 4              86301.070          5
# 5                   16VD          3
# 6            58-02368510          3
# 7   A COOEOGAIEMS GTILNC          2
# 8              .11731193          2
# 9   ldnoznagrn  ehaeezls          1
# 10           91555800 86          1
# 11           8850990-282          1
# 12           -0856360641          1
# 13           7706-614008          1
# 14             .57342035          1

# %% [markdown]
# * What's PDV and why is the most common value of this column?

# %%
errors_dict['birthDate'].rename(columns={'index':'birthDate', 'birthDate':'frequency'})
# Out:
#   birthDate  frequency
# 0       NaT     463132

# %% [markdown]
# * In the errors of ```birthDate``` is obviously that the error is actually a null value that wasn't catched by the program

# %%
errors_dict['custEmail'].rename(columns={'index':'custEmail', 'custEmail':'frequency'})
# Out:
#                                          custEmail  frequency
# 0                                                1         89
# 1  sarmientoney@gmail.com    ledarouse@hotmail.com         33
# 2                                                S         18
# 3                                          COO@MII          7
# 4                                                M          4
# 5                                              www          2
# 6                                  LEIDISL@HOTMAIL          2

# %% [markdown]
# * Some emails wasn't input in a correct format, we should check closely over the design of our applications to solve this problem

# %% [markdown]
# Now that we know how much unique values are inside the columns, we can notice that some variables has a few number of them. A good threshold for capture them could be ```unique_values > 150```. Those variables are useful grouping the dataframe in the BI process and are also good candidates for cluster the df, we could use them later.
#
# After that, there are four variables which don't increase our information but make the dataframe bigger in memory. Those are  ```'dayOfYear'```, ```'dayOfWeek'```, ```'yearMonth'```and```'dayName'```. Since we have ```date``` in our dataset and that variable is the base granular data of the mentioned variables, those ones are irrelevants at least in this part of the process. We can calculate them if is necessary after process the data, in the BI stage.

# %%
df = df.drop(columns=['dayOfYear','dayOfWeek', 'yearMonth', 'dayName'])

# %% [markdown]
# ### CLEANING WRONG VALUES

# %% [markdown]
# The wrong data must be cleaned in order to keep de quality of data. How are we going to do that? The wrong values in birthDate are, as we know, null values which are not consider like that by the program, lets check if there are more null values in that column that are not ```NaT```

# %% [markdown]
# **Cleaning ```birthDate```**

# %%
df.birthDate.isna().sum()
# Out:
# 4309

# %% [markdown]
# There are 4309 null values that are not ```Nat```, how they look like?

# %%
df.birthDate[df.birthDate.isna()]
# Out:
# 0         None
# 1         None
# 218       None
# 219       None
# 220       None
#           ...
# 537408    None
# 537409    None
# 537484    None
# 537485    None
# 537522    None
# Name: birthDate, Length: 4309, dtype: object

# %% [markdown]
# Those nulls are python builtin null values. We want to homogenenize the null values in that column, then we will replace ```NaT``` with ```None```

# %%
df.birthDate = df.birthDate.replace('NaT', None)

# %% [markdown]
# **Cleaning ```custEmail```**

# %%
df.custEmail.isna().sum()
# Out:
# 498051

# %% [markdown]
# What about ```custEmail```. We found seven wrong emails in that column, how can we clean them? For the business is not useful to have those wrong emails in there because could create errors in email ads campaigns or related problems. Also, are not useful at all because we can't contact any client with that information. Finally, as we can see in the last cell, there are few customers whom provides an email direction. Considering that, the best option is to delete those wrong values.

# %%
# Saving the wrong values table into a variable
custEmailWrong = errors_dict['custEmail'].rename(columns={'index':'custEmail', 'custEmail':'frequency'})

# %%
df.custEmail = df.custEmail.replace({x:None for x in custEmailWrong.custEmail.tolist()})

# %% [markdown]
# **Cleaning ```customerID```**

# %% [markdown]
# The last variable we're going to clean is ```customerID```. This variable wrong values are so particular, first we have the value ```PDV``` which is actually the most common in the column, and the other wrong values can not be deleted just like that because, what if those are unique customers ids that, even if doesn't match with the pattern, work just like any other customer id? In order to solve this problem lets set a hypothesis:
#
# * ```PDV``` is a value that represent the null value in customerID column.
#
# How can we check that? Lets filter our dataframe for watch only the rows with ```customerID``` equals ```PDV``` and then we will check the content of the customer related columns ```customerID```, ```custCity```, ```custCreationDate```, ```custEmail```, ```custHood```, ```birthDate``` and ```gender```

# %%
df[df.customerID == 'PDV'][['customerID', 
                            'custCity', 'custCreationDate', 
                            'custEmail', 'custHood', 'birthDate', 'gender']].drop_duplicates()
# Out:
#    customerID  custCity         custCreationDate custEmail custHood birthDate  \
# 22        PDV       1.0  2013-01-02 00:00:00.000      None     None      None
#
#     gender
# 22     2.0

# %%
df[(df.customerID == 'PDV')].gender.value_counts()
# Out:
# 2.0    396849
# Name: gender, dtype: int64

# %% [markdown]
# There are two things that call my attention in here. First, ```PDV``` is a created client which has a city, maybe is a special client which is also the best customer of the enterprise, maybe our business is mainly a provider of another business and the final customer (normal people) is not our main market. Our hypotesis is false. Second, ```PDV``` has a gender. As we saw in the profiler, gender has three unique values which are 0, 1, 2 and a four value which is `nan`. Then the question is, those values are male, female and _enterprise_ or there is a mistake in here? Lets check the gender unique values without consider ```PDV```.
#
# **Note:** Save a customer id as `PDV` is a bad practice!

# %%
df[~(df.customerID == 'PDV')].gender.value_counts()
# Out:
# 0.0    73237
# 2.0    40181
# 1.0    23845
# Name: gender, dtype: int64

# %% [markdown]
# There are an important number of `2` gender values, so we can not say that there are two gender values, actually there could be an `others` or `prefer dont say` value inside of them. Then we are going to make an assumption: ```PDV``` is an enterprise customer, so has no gender. That means that the ```PDV``` gender can be deleted. But what happen if our assumption is false? Ok, in that case we can add the value 2 to the gender column for `PDV` and there is no lost of information.

# %%
def pdv_gender(value):
    #This function creates a column of kind of bool values which later
    #multiplies the original gender column in order to replace with nan the
    #gender of PDV
    if value == 'PDV':
        return np.nan
    else:
        return 1

# %%
df['gender_bool_multiplier'] = df.customerID.apply(pdv_gender)

# %%
df['gender_test'] = df.gender_bool_multiplier * df.gender
df = df.drop(columns='gender_bool_multiplier')

# %%
## Checking if gender_test matches with our expectations
df[(df.customerID == 'PDV')].gender_test.value_counts()
# Out:
# Series([], Name: gender_test, dtype: int64)

# %%
df[~(df.customerID == 'PDV')].gender_test.value_counts()
# Out:
# 0.0    73237
# 2.0    40181
# 1.0    23845
# Name: gender_test, dtype: int64

# %%
# Replacing gender with gender_test but keeping the previous column name
df = df.drop(columns='gender').rename(columns={'gender_test':'gender'})

# %%
# last check
df[(df.customerID == 'PDV')].gender.value_counts()
# Out:
# Series([], Name: gender, dtype: int64)

# %%
df[~(df.customerID == 'PDV')].gender.value_counts()
# Out:
# 0.0    73237
# 2.0    40181
# 1.0    23845
# Name: gender, dtype: int64

# %% [markdown]
# Now that we know that `PDV` is actually a client, what happens with the other wrong ids? Lets check them using a drop_duplicates over all the customer related variables but considering only those wrongs ids.

# %%
# Saving errors df of customerID
errors_cust_id = errors_dict['customerID'].rename(columns={'index':'customerID', 'customerID':'frequency'})
errors_cust_id_clean = errors_cust_id.customerID.tolist()
errors_cust_id_clean.remove('PDV')

# %%
df[df.customerID.isin(errors_cust_id_clean)][['customerID', 
                            'custCity', 'custCreationDate', 
                            'custEmail', 'custHood', 'birthDate', 'gender']].drop_duplicates()
# Out:
#                   customerID  custCity         custCreationDate  \
# 9773    ldnoznagrn  ehaeezls     836.0  2020-04-17 00:00:00.000
# 15323              64617-248       1.0  2018-08-21 00:00:00.000
# 24889   A COOEOGAIEMS GTILNC       1.0  2013-03-06 00:00:00.000
# 28117                OOACRGS       1.0  2013-07-31 00:00:00.000
# 33599                      p       1.0  2018-10-03 00:00:00.000
# 40379            91555800 86       1.0  2015-10-22 00:00:00.000
# 47875                   16VD     421.0  2013-02-02 00:00:00.000
# 82256              .11731193       1.0  2021-01-27 00:00:00.000
# 82345            8850990-282     836.0  2021-01-27 00:00:00.000
# 121267           -0856360641       1.0  2015-01-27 00:00:00.000
# 155049           58-02368510       1.0  2020-06-16 00:00:00.000
# 301592           7706-614008       1.0  2018-12-26 00:00:00.000
# 312349             .57342035       1.0  2020-01-07 00:00:00.000
# 412781             86301.070     836.0  2020-01-20 00:00:00.000
#
#                        custEmail custHood                birthDate  gender
# 9773                        None     None                     None     0.0
# 15323   JULIANTAYRONA1@GMAIL.COM     None  1984-06-08 00:00:00.000     0.0
# 24889                       None   CENTRO                     None     0.0
# 28117                       None     None                     None     0.0
# 33599                       None     None                     None     0.0
# 40379                       None     None                     None     0.0
# 47875                       None     None  2013-02-02 00:00:00.000     0.0
# 82256                       None     None                     None     0.0
# 82345                       None     None                     None     0.0
# 121267                      None     None                     None     0.0
# 155049                      None     None                     None     0.0
# 301592                      None    PRADO                     None     0.0
# 312349                      None     None                     None     0.0
# 412781                      None     None                     None     0.0

# %% [markdown]
# As we can see, those wrong values are customers which have even email, hood, city, and birthdate as any other client. The best option we can take here is let the wrong values as them are and wait for more info after take a different decission. We should also review the algorithm that creates the ids in order to avoid more of this wrong values in the future

# %% [markdown]
# # Solving Redundancy
# As we can see, our data creates a record for each sale done in the store. We have the ```paymentMethod```, the ```value``` of the transaction but also we have values like the ```birthDate``` of the customer which, even if can gave us an important info about our clients, we don't need to repeat them for each buy done by an specific client. That increases the size of our data unnecessarily, so we will create a relational model over the data to solve that problem.
#
# The excecise requires additional info about customer city from [here](https://www.datos.gov.co/Mapas-Nacionales/Departamentos-y-municipios-de-Colombia/xdk5-pm3f) but there is not a clear rule to match custCity with that information. Lets take a look over the data.

# %%
dptos = pd.read_parquet('cityCol.parquet')

# %%
dptos.head(5)
# Out:
#                             region  dane_dpto       dpto  dane_munipo  \
# 0  Región Eje Cafetero - Antioquia          5  Antioquia        5.001
# 1  Región Eje Cafetero - Antioquia          5  Antioquia        5.002
# 2  Región Eje Cafetero - Antioquia          5  Antioquia        5.004
# 3  Región Eje Cafetero - Antioquia          5  Antioquia        5.021
# 4  Región Eje Cafetero - Antioquia          5  Antioquia        5.030
#
#        munipo
# 0    Medellín
# 1   Abejorral
# 2    Abriaquí
# 3  Alejandría
# 4       Amagá

# %%
print('in dane_munipo.', ' max:', dptos.dane_munipo.max(), ',', ' min:', dptos.dane_munipo.min())
# Out:
# in dane_munipo.  max: 99.773 ,  min: 5.001

# %%
df.custCity.unique()
# Out:
# array([ nan,   1., 770., 372., 836., 101., 205., 520., 442., 758.,   2.,
#        634., 433., 551., 675., 558., 541., 573.,  52., 638., 161., 104.,
#        685., 560.,  78., 642., 421., 745., 137., 555., 683., 296., 248.,
#        140., 436., 654., 838., 606.,   5., 430., 873., 832.,  99., 647.,
#        849., 605.,   6., 141., 628., 897., 549., 713.])

# %% [markdown]
# We have here a code with four to five characters and in our data frame `custCity` has one to three. We also notice that the first part of `dane_munipo` code is the same that `dane_dpto`, that may give us a clue: if we drop the dpto code inside the munipo code we can have our desired data. Lets do that

# %%
dptos['munip_tres'] = (dptos.dane_munipo)-(dptos.dane_munipo).astype(int)

# %%
dptos.sort_values(by='munip_tres').head(50).reset_index()
# Out:
#     index                           region  dane_dpto  \
# 0     555                    Región Caribe         44
# 1    1085            Región Centro Oriente         54
# 2     519                Región Centro Sur         41
# 3     671  Región Eje Cafetero - Antioquia         63
# 4     615                  Región Pacífico         52
# 5     592                     Región Llano         50
# 6     568                    Región Caribe         47
# 7     953            Región Centro Oriente         11
# 8     170            Región Centro Oriente         15
# 9     121                    Región Caribe          8
# 10   1086                    Región Caribe         13
# 11      0  Región Eje Cafetero - Antioquia          5
# 12    944            Región Centro Oriente         25
# 13    353                    Región Caribe         20
# 14    497                  Región Pacífico         27
# 15    278  Región Eje Cafetero - Antioquia         17
# 16    314                  Región Pacífico         19
# 17    376                    Región Caribe         23
# 18    304                Región Centro Sur         18
# 19    871                Región Centro Sur         97
# 20    903                     Región Llano         95
# 21    830                     Región Llano         81
# 22    844                Región Centro Sur         86
# 23    948                    Región Caribe         88
# 24    831                     Región Llano         85
# 25    681  Región Eje Cafetero - Antioquia         66
# 26   1016                  Región Pacífico         76
# 27    863                     Región Llano         94
# 28   1077                Región Centro Sur         73
# 29    693            Región Centro Oriente         68
# 30    878                     Región Llano         99
# 31    854                Región Centro Sur         91
# 32    766                    Región Caribe         70
# 33      1  Región Eje Cafetero - Antioquia          5
# 34   1028            Región Centro Oriente         54
# 35      2  Región Eje Cafetero - Antioquia          5
# 36    593                     Región Llano         50
# 37    520                Región Centro Sur         41
# 38    498                  Región Pacífico         27
# 39    138                    Región Caribe         13
# 40    832                     Región Llano         85
# 41    354                    Región Caribe         20
# 42    521                Región Centro Sur         41
# 43    355                    Región Caribe         20
# 44    279  Región Eje Cafetero - Antioquia         17
# 45    694            Región Centro Oriente         68
# 46    900                     Región Llano         95
# 47    833                     Región Llano         85
# 48    522                Región Centro Sur         41
# 49   1053            Región Centro Oriente         25
#
#                                                  dpto  dane_munipo  \
# 0                                          La Guajira       44.001
# 1                                  Norte de Santander       54.001
# 2                                               Huila       41.001
# 3                                             Quindío       63.001
# 4                                              Nariño       52.001
# 5                                                Meta       50.001
# 6                                           Magdalena       47.001
# 7                                         Bogotá D.C.       11.001
# 8                                              Boyacá       15.001
# 9                                           Atlántico        8.001
# 10                                            Bolívar       13.001
# 11                                          Antioquia        5.001
# 12                                       Cundinamarca       25.001
# 13                                              Cesar       20.001
# 14                                              Chocó       27.001
# 15                                             Caldas       17.001
# 16                                              Cauca       19.001
# 17                                            Córdoba       23.001
# 18                                            Caquetá       18.001
# 19                                             Vaupés       97.001
# 20                                           Guaviare       95.001
# 21                                             Arauca       81.001
# 22                                           Putumayo       86.001
# 23  Archipiélago de San Andrés, Providencia y Sant...       88.001
# 24                                           Casanare       85.001
# 25                                          Risaralda       66.001
# 26                                    Valle del Cauca       76.001
# 27                                            Guainía       94.001
# 28                                             Tolima       73.001
# 29                                          Santander       68.001
# 30                                            Vichada       99.001
# 31                                           Amazonas       91.001
# 32                                              Sucre       70.001
# 33                                          Antioquia        5.002
# 34                                 Norte de Santander       54.003
# 35                                          Antioquia        5.004
# 36                                               Meta       50.006
# 37                                              Huila       41.006
# 38                                              Chocó       27.006
# 39                                            Bolívar       13.006
# 40                                           Casanare       85.010
# 41                                              Cesar       20.011
# 42                                              Huila       41.013
# 43                                              Cesar       20.013
# 44                                             Caldas       17.013
# 45                                          Santander       68.013
# 46                                           Guaviare       95.015
# 47                                           Casanare       85.015
# 48                                              Huila       41.016
# 49                                       Cundinamarca       25.019
#
#                    munipo  munip_tres
# 0                Riohacha       0.001
# 1                  Cúcuta       0.001
# 2                   Neiva       0.001
# 3                 Armenia       0.001
# 4                   Pasto       0.001
# 5           Villavicencio       0.001
# 6             Santa Marta       0.001
# 7             Bogotá D.C.       0.001
# 8                   Tunja       0.001
# 9            Barranquilla       0.001
# 10              Cartagena       0.001
# 11               Medellín       0.001
# 12           Agua de Dios       0.001
# 13             Valledupar       0.001
# 14                 Quibdó       0.001
# 15              Manizales       0.001
# 16                Popayán       0.001
# 17               Montería       0.001
# 18              Florencia       0.001
# 19                   Mitú       0.001
# 20  San José del Guaviare       0.001
# 21                 Arauca       0.001
# 22                  Mocoa       0.001
# 23             San Andrés       0.001
# 24                  Yopal       0.001
# 25                Pereira       0.001
# 26                   Cali       0.001
# 27                Inírida       0.001
# 28                 Ibagué       0.001
# 29            Bucaramanga       0.001
# 30         Puerto Carreño       0.001
# 31                Leticia       0.001
# 32              Sincelejo       0.001
# 33              Abejorral       0.002
# 34                 Abrego       0.003
# 35               Abriaquí       0.004
# 36                Acacias       0.006
# 37                Acevedo       0.006
# 38                 Acandí       0.006
# 39                   Achí       0.006
# 40                Aguazul       0.010
# 41              Aguachica       0.011
# 42                 Agrado       0.013
# 43        Agustín Codazzi       0.013
# 44                Aguadas       0.013
# 45                 Aguada       0.013
# 46                Calamar       0.015
# 47                Chámeza       0.015
# 48                   Aipe       0.016
# 49                  Albán       0.019

# %% [markdown]
# What a big deal we have encounter here! The code `001` es repeated 33 time! Those values seems to be de Departament capitals except for Agua de Dios, Cundinamarca. Maybe that value has te code `001` because of its place in the list of Cundinamarca's municipes alphabeticaly. Lets check

# %%
dptos[dptos.dpto=='Cundinamarca'].sort_values(by='munipo').head(5)
# Out:
#                      region  dane_dpto          dpto  dane_munipo  \
# 944   Región Centro Oriente         25  Cundinamarca       25.001
# 1053  Región Centro Oriente         25  Cundinamarca       25.019
# 399   Región Centro Oriente         25  Cundinamarca       25.035
# 1062  Región Centro Oriente         25  Cundinamarca       25.040
# 463   Región Centro Oriente         25  Cundinamarca       25.599
#
#             munipo  munip_tres
# 944   Agua de Dios       0.001
# 1053         Albán       0.019
# 399       Anapoima       0.035
# 1062      Anolaima       0.040
# 463          Apulo       0.599

# %% [markdown]
# That's exactly the reason.
#
# How we are facing a problem, our `custCity` variable has not enought information to make a perfect match with the city code table. The values different to `001` have not a clear pattern which specifies why a code is assigned to a city, then we basically have two big groups not perfectly divided: **Capital** and **Non capital** cities. Is not a perfect division because Agua de Dios is not capital from Cundinamarca, but we can't filter our `df` to select Agua de Dios. Then, lets make the next assumption: Agua de Dios is a very small town in comparison with the whole departament capitals together, so we can say that the code `1` in `custCity` goes for Capital cities and the error margin will be almost irrelevant. We can be wrong if the main city of our business is Agua de Dios, but even in that case, the number of registers for `1` is around 48 bigger than the whole population in Agua de Dios! Our assumtion seems very secure.

# %% [markdown]
# Our relational model will be something like this:

# %%
Image('pruebainc.png')

# %% [markdown]
# Notice that Sales has a different id, it comes from add `ticketNumber` to `ticketNumberDetail`. Now lets create our model...

# %%
df = df.rename(columns={'custCity':'cityId'})

# %%
total_columns = set(df.columns.tolist())

# %%
customers = set(('customerID', 'cityId', 'custCreationDate', 'custEmail', 'custHood', 'birthDate', 'gender'))

# %%
col_nocost = total_columns - customers

# %%
items = set(('itemApplications', 'itemCreationDate', 'itemGroup', 'itemID', 'itemLevel', 'itemLine', 
             'itemName', 'itemRegulated', 'itemSubline', 'brand', 'businessUnit', 'category', 'unitOfMeasure'))

# %%
col_nocost_noitem = col_nocost - items
col_nocost_noitem.add('customerID')
col_nocost_noitem.add('itemID')

# %%
# Creating customers
customers_df = df[list(customers)].drop_duplicates()
customers_df = customers_df.dropna(how='all')

# %%
#Checking that customers has one unique id per row
not_unique_customers = customers_df.customerID.value_counts()[customers_df.customerID.value_counts() > 1]
not_unique_customers
# Out:
# 0997609     2
# 94277212    2
# Name: customerID, dtype: int64

# %%
#There are two repeated values in customerID which means that a single customer has different features. 
#Lets check them
customers_df[customers_df.customerID.isin(not_unique_customers.index.tolist())].sort_values(by='customerID')
# Out:
#                       birthDate         custCreationDate custHood customerID  \
# 54583                      None  2020-07-09 00:00:00.000     None    0997609
# 316043  1976-04-04 00:00:00.000  2020-03-06 00:00:00.000     None    0997609
# 91715                      None  2019-12-27 00:00:00.000     None   94277212
# 473969                     None  2019-08-21 00:00:00.000     None   94277212
#
#         cityId                 custEmail  gender
# 54583      1.0                      None     0.0
# 316043     1.0  ospinoramos1@hotmail.com     2.0
# 91715      1.0                      None     0.0
# 473969   758.0                      None     0.0

# %%
# Creating items
items_df = df[list(items)].drop_duplicates()
items_df = items_df.dropna(how='all')

# %%
#Checking that items has one unique id per row
not_unique_items = items_df.itemID.value_counts()[items_df.itemID.value_counts() > 1]
not_unique_items
# Out:
# Series([], Name: itemID, dtype: int64)

# %%
# Creating sales. Is not necessary to apply drop_duplicates since the PK has as much unique values as rows
# has the dataframe, we saw it in the profiling. 
sales_df = df[list(col_nocost_noitem)]
sales_df['salesID'] = sales_df.ticketNumber.fillna('') + sales_df.ticketNumberDetail.fillna('')
# Out:
# /tmp/ipykernel_37/3123718179.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_df['salesID'] = sales_df.ticketNumber.fillna('') + sales_df.ticketNumberDetail.fillna('')

# %%
#Checking that items has one unique id per row
not_unique_sales = sales_df.salesID.value_counts()[sales_df.salesID.value_counts() > 1]
not_unique_sales
# Out:
# Series([], Name: salesID, dtype: int64)

# %%
#Creating city_df
city_df = df['cityId'].drop_duplicates().to_frame()

# %%
def city_grouper(value):
    if value == 1:
        return 'Capital'
    elif value > 1:
        return 'Non Capital'
    else:
        return None

# %%
city_df['cityGrouper'] = city_df.cityId.apply(city_grouper)
city_df = city_df.dropna(how='all')

# %% [markdown]
# Notice that customersID has repeated values, what we can do with those values? The customer `0997609` has two entries but one of them doesn't give us additional info about the customer, then we can drop the one with less information. The customer `94277212` is different, it seems that he has change the city where is living. That opens a question, what can we do when our clients change its data? There are two options: our database could record just the current values for each client variable or we can record the client changes history. I preffer to keep as much data as possible from our business, then I will keep both records, but how can I avoid conflicts for future process with the data? I will create a new column called `status` which will have only two values: `0` for inactive and `1` for active. All our clients except the oldest entry of `94277212` will be `1`

# %%
customers_df = customers_df.drop(54583)

# %%
customers_df['status'] = 1
customers_df.loc[473969, 'status'] = 0

# %%
customers_df[customers_df.status == 0]
# Out:
#        birthDate         custCreationDate custHood customerID  cityId  \
# 473969      None  2019-08-21 00:00:00.000     None   94277212   758.0
#
#        custEmail  gender  status
# 473969      None     0.0       0

# %% [markdown]
# # Exporting Dfs

# %%
sales_df.to_parquet('sales.parquet')
customers_df.to_parquet('customers.parquet')
items_df.to_parquet('items.parquet')
city_df.to_parquet('cities.parquet')
